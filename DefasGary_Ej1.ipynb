# %% [markdown]
# # Tarea Mínimos Cuadrados
# Gary Defas

# %% [markdown]
# ## Ejercicio 1

# %%
xs = [
    4.0, 
    4.2, 
    4.5, 
    4.7, 
    5.1, 
    5.5, 
    5.9, 
    6.3, 
    6.8, 
    7.1
]

ys = [
    102.56,
    130.11,
    113.18,
    142.05,
    167.53,
    195.14,
    224.87,
    256.73,
    299.50,
    326.72
]

# %% [markdown]
# ### Ecuacion grado 1

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados  # no modificar esta función

pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1])
# Out:
# [01-28 21:37:12][INFO] 2026-01-28 21:37:12.390809
# [01-28 21:37:12][INFO] 2026-01-28 21:37:12.818860
# [01-28 21:37:12][INFO] Se ajustarán 2 parámetros.
# [01-28 21:37:12][INFO]
# [[  54.1          10.         1958.39      ]
#  [   0.           -1.97948244  379.21423845]]

# %%
import matplotlib.pyplot as plt
import numpy as np

def f_lineal(x):
    return pars[0] * x + pars[1]

x = np.linspace(3.5, 7.5, 100)
y = f_lineal(x)
plt.scatter(xs, ys, color='red', label='Datos')
plt.plot(x, y, label='Ajuste por mínimos cuadrados')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por Mínimos Cuadrados - Regresión Lineal')
plt.legend()
plt.grid()
plt.show()

# %%
# Calcular el error entre los puntos dados y la ecuación ajustada
errores = []
for xi, yi in zip(xs, ys):
    y_ajustado = f_lineal(xi)
    error = abs(yi - y_ajustado)
    errores.append(error)
    print(f"x = {xi}, y_real = {yi}, y_ajustado = {y_ajustado:.2f}, error = {error:.2f}")

# Error absoluto medio (MAE)
mae = sum(errores) / len(errores)
print(f"\nError Absoluto Medio (MAE): {mae:.4f}")

# Error cuadrático medio (MSE)
mse = sum((yi - f_lineal(xi))**2 for xi, yi in zip(xs, ys)) / len(xs)
print(f"Error Cuadrático Medio (MSE): {mse:.4f}")

# Raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse:.4f}")
# Out:
# x = 4.0, y_real = 102.56, y_ajustado = 94.87, error = 7.69
# x = 4.2, y_real = 130.11, y_ajustado = 109.19, error = 20.92
# x = 4.5, y_real = 113.18, y_ajustado = 130.67, error = 17.49
# x = 4.7, y_real = 142.05, y_ajustado = 145.00, error = 2.95
# x = 5.1, y_real = 167.53, y_ajustado = 173.64, error = 6.11
# x = 5.5, y_real = 195.14, y_ajustado = 202.28, error = 7.14
# x = 5.9, y_real = 224.87, y_ajustado = 230.93, error = 6.06
# x = 6.3, y_real = 256.73, y_ajustado = 259.57, error = 2.84
# x = 6.8, y_real = 299.5, y_ajustado = 295.38, error = 4.12
# x = 7.1, y_real = 326.72, y_ajustado = 316.86, error = 9.86
#
# Error Absoluto Medio (MAE): 8.5187
# Error Cuadrático Medio (MSE): 105.8839
# Raíz del Error Cuadrático Medio (RMSE): 10.2900

# %% [markdown]
# ### Ecuacion grado 2

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    c_2 = sum(xi**2 for xi in xs)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_2, c_1, c_0, c_ind)


def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    c_2 = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        c_2 += xi*xi*xi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_2, c_1, c_0, c_ind)

def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * xi * yi

        c_2 += xi*xi*xi * xi

        # coeficiente del parámetro 1
        c_1 += xi * xi * xi

        # coeficiente del parámetro 0
        c_0 += xi * xi

    return (c_2, c_1, c_0, c_ind)

# %%
pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1, der_parcial_2])
# Out:
# [01-28 21:37:15][INFO] Se ajustarán 3 parámetros.
# [01-28 21:37:15][INFO]
# [[ 3.03390000e+02  5.41000000e+01  1.00000000e+01  1.95839000e+03]
#  [ 0.00000000e+00 -1.04201358e+01 -3.90557039e+00  2.01110079e+00]
#  [-1.81898940e-12 -1.16634374e+02 -4.34612706e+01  3.54878088e+01]]
# [01-28 21:37:15][INFO]
# [[ 3.03390000e+02  5.41000000e+01  1.00000000e+01  1.95839000e+03]
#  [ 0.00000000e+00 -1.04201358e+01 -3.90557039e+00  2.01110079e+00]
#  [-1.81898940e-12  0.00000000e+00  2.54451185e-01  1.29772113e+01]]

# %%
import matplotlib.pyplot as plt
import numpy as np

def f_cuadratica(x):
    return pars[0] * x**2 + pars[1] * x + pars[2]
x = np.linspace(3.5, 7.5, 100)
y = f_cuadratica(x)
plt.scatter(xs, ys, color='red', label='Datos')
plt.plot(x, y, label='Ajuste por mínimos cuadrados (cuadrática)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por Mínimos Cuadrados - Regresión Cuadrática')
plt.legend()
plt.grid()
plt.show()

# %%
# Calcular el error entre los puntos dados y la ecuación ajustada
errores = []
for xi, yi in zip(xs, ys):
    y_ajustado = f_cuadratica(xi)
    error = abs(yi - y_ajustado)
    errores.append(error)
    print(f"x = {xi}, y_real = {yi}, y_ajustado = {y_ajustado:.2f}, error = {error:.2f}")

# Error absoluto medio (MAE)
mae = sum(errores) / len(errores)
print(f"\nError Absoluto Medio (MAE): {mae:.4f}")

# Error cuadrático medio (MSE)
mse = sum((yi - f_cuadratica(xi))**2 for xi, yi in zip(xs, ys)) / len(xs)
print(f"Error Cuadrático Medio (MSE): {mse:.4f}")

# Raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse:.4f}")
# Out:
# x = 4.0, y_real = 102.56, y_ajustado = 105.24, error = 2.68
# x = 4.2, y_real = 130.11, y_ajustado = 114.85, error = 15.26
# x = 4.5, y_real = 113.18, y_ajustado = 130.51, error = 17.33
# x = 4.7, y_real = 142.05, y_ajustado = 141.77, error = 0.28
# x = 5.1, y_real = 167.53, y_ajustado = 166.25, error = 1.28
# x = 5.5, y_real = 195.14, y_ajustado = 193.37, error = 1.77
# x = 5.9, y_real = 224.87, y_ajustado = 223.12, error = 1.75
# x = 6.3, y_real = 256.73, y_ajustado = 255.49, error = 1.24
# x = 6.8, y_real = 299.5, y_ajustado = 299.66, error = 0.16
# x = 7.1, y_real = 326.72, y_ajustado = 328.13, error = 1.41
#
# Error Absoluto Medio (MAE): 4.3159
# Error Cuadrático Medio (MSE): 55.1656
# Raíz del Error Cuadrático Medio (RMSE): 7.4274

# %% [markdown]
# ### Ecuacion grado 3

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_3(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    c_3 = sum(xi**3 for xi in xs)

    c_2 = sum(xi**2 for xi in xs)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_3, c_2, c_1, c_0, c_ind)


def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        c_3 += xi*xi*xi*xi

        c_2 += xi*xi*xi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_3, c_2, c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * xi * yi

        c_3 += xi*xi*xi*xi*xi

        c_2 += xi*xi*xi*xi

        # coeficiente del parámetro 1
        c_1 += xi*xi*xi

        # coeficiente del parámetro 0
        c_0 += xi*xi

    return (c_3, c_2, c_1, c_0, c_ind)

def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0

    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * xi * xi* yi

        c_3 += xi*xi*xi*xi*xi*xi

        c_2 += xi*xi*xi*xi*xi

        # coeficiente del parámetro 1
        c_1 += xi*xi*xi*xi

        # coeficiente del parámetro 0
        c_0 += xi*xi*xi

    return (c_3, c_2, c_1, c_0, c_ind)

# %%
pars = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_0, der_parcial_1, der_parcial_2, der_parcial_3])
# Out:
# [01-28 21:37:15][INFO] Se ajustarán 4 parámetros.
# [01-28 21:37:15][INFO]
# [[ 1.75983100e+03  3.03390000e+02  5.41000000e+01  1.00000000e+01
#    1.95839000e+03]
#  [ 0.00000000e+00 -6.15116038e+02 -2.26320843e+02 -6.37360337e+01
#   -3.93510152e+03]
#  [ 0.00000000e+00 -5.43259214e+01 -2.01074437e+01 -5.69620032e+00
#   -3.48664074e+02]
#  [ 0.00000000e+00 -5.31922790e+03 -1.94618222e+03 -5.45030907e+02
#   -3.39401892e+04]]
# [01-28 21:37:15][INFO]
# [[ 1.75983100e+03  3.03390000e+02  5.41000000e+01  1.00000000e+01
#    1.95839000e+03]
#  [ 0.00000000e+00 -5.43259214e+01 -2.01074437e+01 -5.69620032e+00
#   -3.48664074e+02]
#  [ 0.00000000e+00  0.00000000e+00  1.34968353e+00  7.60325979e-01
#    1.27167205e+01]
#  [ 0.00000000e+00  0.00000000e+00  2.26030819e+01  1.27026172e+01
#    1.98645765e+02]]
# [01-28 21:37:15][INFO]
# [[ 1.75983100e+03  3.03390000e+02  5.41000000e+01  1.00000000e+01
#    1.95839000e+03]
#  [ 0.00000000e+00 -5.43259214e+01 -2.01074437e+01 -5.69620032e+00
#   -3.48664074e+02]
#  [ 0.00000000e+00  0.00000000e+00  1.34968353e+00  7.60325979e-01
#    1.27167205e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -3.05235122e-02
#   -1.43205107e+01]]

# %%
def f_cubica(x):
    return pars[0] * x**3 + pars[1] * x**2 + pars[2] * x + pars[3]

x = np.linspace(3.5, 7.5, 100)
y = f_cubica(x)
plt.scatter(xs, ys, color='red', label='Datos')
plt.plot(x, y, label='Ajuste por mínimos cuadrados (cúbica)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por Mínimos Cuadrados - Regresión Cúbica')
plt.legend()
plt.grid()
plt.show()

# %%
# Calcular el error entre los puntos dados y la ecuación ajustada
errores = []
for xi, yi in zip(xs, ys):
    y_ajustado = f_cubica(xi)
    error = abs(yi - y_ajustado)
    errores.append(error)
    print(f"x = {xi}, y_real = {yi}, y_ajustado = {y_ajustado:.2f}, error = {error:.2f}")

# Error absoluto medio (MAE)
mae = sum(errores) / len(errores)
print(f"\nError Absoluto Medio (MAE): {mae:.4f}")

# Error cuadrático medio (MSE)
mse = sum((yi - f_cubica(xi))**2 for xi, yi in zip(xs, ys)) / len(xs)
print(f"Error Cuadrático Medio (MSE): {mse:.4f}")

# Raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse:.4f}")
# Out:
# x = 4.0, y_real = 102.56, y_ajustado = 107.80, error = 5.24
# x = 4.2, y_real = 130.11, y_ajustado = 115.09, error = 15.02
# x = 4.5, y_real = 113.18, y_ajustado = 128.79, error = 15.61
# x = 4.7, y_real = 142.05, y_ajustado = 139.58, error = 2.47
# x = 5.1, y_real = 167.53, y_ajustado = 164.60, error = 2.93
# x = 5.5, y_real = 195.14, y_ajustado = 193.36, error = 1.78
# x = 5.9, y_real = 224.87, y_ajustado = 224.85, error = 0.02
# x = 6.3, y_real = 256.73, y_ajustado = 258.07, error = 1.34
# x = 6.8, y_real = 299.5, y_ajustado = 300.52, error = 1.02
# x = 7.1, y_real = 326.72, y_ajustado = 325.72, error = 1.00
#
# Error Absoluto Medio (MAE): 4.6428
# Error Cuadrático Medio (MSE): 51.8383
# Raíz del Error Cuadrático Medio (RMSE): 7.1999

# %% [markdown]
# ### Ecuacion $be^{ax}$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
import numpy as np

Y = np.log(ys)

pars = ajustar_min_cuadrados(xs, Y, gradiente=[der_parcial_0, der_parcial_1])

a = pars[0]

B = pars[1]
b = np.exp(B)

print(f"y = {b:.4f} * e^({a:.4f} * x)")
# Out:
# [01-28 21:46:15][INFO] Se ajustarán 2 parámetros.
# [01-28 21:46:15][INFO]
# [[54.1        10.         52.03363187]
#  [ 0.         -1.97948244 -6.35394989]]
# y = 24.7767 * e^(0.3685 * x)

# %%
def f_exponencial(x):
    return b * np.exp(a * x)

x = np.linspace(3.5, 7.5, 100)
y = f_exponencial(x)
plt.scatter(xs, ys, color='red', label='Datos')
plt.plot(x, y, label='Ajuste por mínimos cuadrados (exponencial)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por Mínimos Cuadrados - Regresión Exponencial')
plt.legend()
plt.grid()
plt.show()

# %%
# Calcular el error entre los puntos dados y la ecuación ajustada
errores = []
for xi, yi in zip(xs, ys):
    y_ajustado = f_exponencial(xi)
    error = abs(yi - y_ajustado)
    errores.append(error)
    print(f"x = {xi}, y_real = {yi}, y_ajustado = {y_ajustado:.2f}, error = {error:.2f}")

# Error absoluto medio (MAE)
mae = sum(errores) / len(errores)
print(f"\nError Absoluto Medio (MAE): {mae:.4f}")

# Error cuadrático medio (MSE)
mse = sum((yi - f_exponencial(xi))**2 for xi, yi in zip(xs, ys)) / len(xs)
print(f"Error Cuadrático Medio (MSE): {mse:.4f}")

# Raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse:.4f}")
# Out:
# x = 4.0, y_real = 102.56, y_ajustado = 108.18, error = 5.62
# x = 4.2, y_real = 130.11, y_ajustado = 116.46, error = 13.65
# x = 4.5, y_real = 113.18, y_ajustado = 130.07, error = 16.89
# x = 4.7, y_real = 142.05, y_ajustado = 140.01, error = 2.04
# x = 5.1, y_real = 167.53, y_ajustado = 162.25, error = 5.28
# x = 5.5, y_real = 195.14, y_ajustado = 188.02, error = 7.12
# x = 5.9, y_real = 224.87, y_ajustado = 217.87, error = 7.00
# x = 6.3, y_real = 256.73, y_ajustado = 252.47, error = 4.26
# x = 6.8, y_real = 299.5, y_ajustado = 303.55, error = 4.05
# x = 7.1, y_real = 326.72, y_ajustado = 339.03, error = 12.31
#
# Error Absoluto Medio (MAE): 7.8216
# Error Cuadrático Medio (MSE): 82.1005
# Raíz del Error Cuadrático Medio (RMSE): 9.0609

# %% [markdown]
# ### Ecuacion forma $bx^{a}$

# %%
import numpy as np

X = np.log(xs)
Y = np.log(ys)

pars = ajustar_min_cuadrados(X, Y, gradiente=[der_parcial_0, der_parcial_1])

B = pars[1]
b = np.exp(B)

print(f"y = {b:.4f} * x^{pars[1]:.4f}")
# Out:
# [01-28 22:00:02][INFO] Se ajustarán 2 parámetros.
# [01-28 22:00:02][INFO]
# [[16.6995268  10.         52.03363187]
#  [ 0.         -0.2193428  -0.41119586]]
# y = 6.5187 * x^1.8747

# %%
def f_potencial(x):
    return b * x**pars[0]
x = np.linspace(3.5, 7.5, 100)
y = f_potencial(x)
plt.scatter(xs, ys, color='red', label='Datos')
plt.plot(x, y, label='Ajuste por mínimos cuadrados (potencial)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por Mínimos Cuadrados - Regresión Potencial')
plt.legend()
plt.grid()
plt.show()

# %%
# Calcular el error entre los puntos dados y la ecuación ajustada
errores = []
for xi, yi in zip(xs, ys):
    y_ajustado = f_potencial(xi)
    error = abs(yi - y_ajustado)
    errores.append(error)
    print(f"x = {xi}, y_real = {yi}, y_ajustado = {y_ajustado:.2f}, error = {error:.2f}")

# Error absoluto medio (MAE)
mae = sum(errores) / len(errores)
print(f"\nError Absoluto Medio (MAE): {mae:.4f}")

# Error cuadrático medio (MSE)
mse = sum((yi - f_potencial(xi))**2 for xi, yi in zip(xs, ys)) / len(xs)
print(f"Error Cuadrático Medio (MSE): {mse:.4f}")

# Raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(mse)
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse:.4f}")
# Out:
# x = 4.0, y_real = 102.56, y_ajustado = 103.33, error = 0.77
# x = 4.2, y_real = 130.11, y_ajustado = 113.89, error = 16.22
# x = 4.5, y_real = 113.18, y_ajustado = 130.68, error = 17.50
# x = 4.7, y_real = 142.05, y_ajustado = 142.51, error = 0.46
# x = 5.1, y_real = 167.53, y_ajustado = 167.71, error = 0.18
# x = 5.5, y_real = 195.14, y_ajustado = 194.95, error = 0.19
# x = 5.9, y_real = 224.87, y_ajustado = 224.23, error = 0.64
# x = 6.3, y_real = 256.73, y_ajustado = 255.55, error = 1.18
# x = 6.8, y_real = 299.5, y_ajustado = 297.57, error = 1.93
# x = 7.1, y_real = 326.72, y_ajustado = 324.31, error = 2.41
#
# Error Absoluto Medio (MAE): 4.1489
# Error Cuadrático Medio (MSE): 58.1557
# Raíz del Error Cuadrático Medio (RMSE): 7.6260
